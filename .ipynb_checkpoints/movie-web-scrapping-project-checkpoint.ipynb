# %% [markdown]
# ## Task:
#
# 1) In this project your task is to do web scrapping for the below link provided, and store the data in the CSV file.
#
# 2) After scrapping the data You are required to load the data in pandas and do some EDA and provide some useful graphical information.
#
# Link to scrap data: https://www.themoviedb.org/movie
#
# ### Data
#
# 1. Name
# 2. Rating
# 3. Genre
# 4. Release date
# 5. Runtime
# 6. Director
# 7. Url

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = 'https://www.themoviedb.org'

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}

# %%
response = requests.get(url+'/movie', headers = header)

# %%
response.status_code
# Out:
# 200

# %%
response_html = response.text

# %%
soup = BeautifulSoup(response_html, 'lxml')

# %%
movies_link = []
for link in soup.find('div',class_='page_wrapper').find_all('h2'):
    movies_link.append(url+link.a['href'])

# %%
movies_link
# Out:
# ['https://www.themoviedb.org/movie/634649',
#  'https://www.themoviedb.org/movie/414906',
#  'https://www.themoviedb.org/movie/833425',
#  'https://www.themoviedb.org/movie/568124',
#  'https://www.themoviedb.org/movie/928381',
#  'https://www.themoviedb.org/movie/753232',
#  'https://www.themoviedb.org/movie/823625',
#  'https://www.themoviedb.org/movie/508947',
#  'https://www.themoviedb.org/movie/476669',
#  'https://www.themoviedb.org/movie/512195',
#  'https://www.themoviedb.org/movie/646385',
#  'https://www.themoviedb.org/movie/768744',
#  'https://www.themoviedb.org/movie/928999',
#  'https://www.themoviedb.org/movie/800510',
#  'https://www.themoviedb.org/movie/774825',
#  'https://www.themoviedb.org/movie/890656',
#  'https://www.themoviedb.org/movie/585083',
#  'https://www.themoviedb.org/movie/524434',
#  'https://www.themoviedb.org/movie/597208',
#  'https://www.themoviedb.org/movie/632727']

# %%
response2 = requests.get(movies_link[0], headers=header)

# %%
response2.status_code
# Out:
# 200

# %%
response_html2 = response2.text

# %%
soup = BeautifulSoup(response_html2, 'lxml')

# %% [markdown]
# # Name

# %%
soup.find('section', class_='header poster').a.text
# Out:
# 'Spider-Man: No Way Home'

# %% [markdown]
# # Rating

# %%
soup.find('div', class_='percent').span['class'][-1].replace('icon-r','')
# Out:
# '83'

# %% [markdown]
# # Genre

# %%
soup.find('span', class_='genres').text.strip().replace('\xa0','')
# Out:
# 'Action,Adventure,Science Fiction'

# %% [markdown]
# # Release date

# %%
soup.find('span', class_='release').text.strip().split()[0]
# Out:
# '12/17/2021'

# %% [markdown]
# # Runtime

# %%
soup.find('span', class_='runtime').text.strip()
# Out:
# '2h 28m'

# %% [markdown]
# # Director

# %%
for profile in soup.find_all('li', class_='profile'):
    if 'Director' in profile.text:
        director = profile.a.text
director
# Out:
# 'Jon Watts'

# %% [markdown]
# # Url

# %%
movies_link[0]
# Out:
# 'https://www.themoviedb.org/movie/634649'

# %% [markdown]
# # Final Code

# %%
def movies_scrape():
    url = 'https://www.themoviedb.org'
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
    page_response = requests.get(url+'/movie', headers = header)
    page_html = page_response.text
    page_soup = BeautifulSoup(page_html, 'lxml')
    
    movie_list = []
    
    for link in page_soup.find('div',class_='page_wrapper').find_all('h2'):
        movie_url = url+link.a['href']
        movie_response = requests.get(movie_url, headers = header)
        movie_html = movie_response.text
        movie_soup = BeautifulSoup(movie_html, 'lxml')
        
        name = movie_soup.find('section', class_='header poster').a.text #name
        #name = movie_soup.find('div', class_='title ott_false').a.text #name
        rating = movie_soup.find('div', class_='percent').span['class'][-1].replace('icon-r','') #rating
        genre = movie_soup.find('span', class_='genres').text.strip().replace('\xa0','') #genre
        release_date = movie_soup.find('span', class_='release').text.strip().split()[0] #release_date
        runtime = movie_soup.find('span', class_='runtime').text.strip() #runtime
        
        for profile in movie_soup.find_all('li', class_='profile'): #director
            if 'Director' in profile.text:
                director = profile.a.text
        
        movie_dict = {
            'Name':name,
            'Rating':rating,
            'Genre':genre,
            'Release Date':release_date,
            'Runtime':runtime,
            'Url':movie_url
        }
        movie_list.append(movie_dict)
    return movie_list

# %%
movies_scrape()
# Out:
# [{'Name': 'Spider-Man: No Way Home',
#   'Rating': '83',
#   'Genre': 'Action,Adventure,Science Fiction',
#   'Release Date': '12/17/2021',
#   'Runtime': '2h 28m',
#   'Url': 'https://www.themoviedb.org/movie/634649'},
#  {'Name': 'The Batman',
#   'Rating': '80',
#   'Genre': 'Crime,Mystery,Thriller',
#   'Release Date': '03/04/2022',
#   'Runtime': '2h 56m',
#   'Url': 'https://www.themoviedb.org/movie/414906'},
#  {'Name': 'No Exit',
#   'Rating': '65',
#   'Genre': 'Horror,Thriller',
#   'Release Date': '02/25/2022',
#   'Runtime': '1h 36m',
#   'Url': 'https://www.themoviedb.org/movie/833425'},
#  {'Name': 'Encanto',
#   'Rating': '77',
#   'Genre': 'Animation,Comedy,Family,Fantasy',
#   'Release Date': '11/24/2021',
#   'Runtime': '1h 42m',
#   'Url': 'https://www.themoviedb.org/movie/568124'},
#  {'Name': 'Restless',
#   'Rating': '59',
#   'Genre': 'Action,Thriller,Crime',
#   'Release Date': '02/25/2022',
#   'Runtime': '1h 35m',
#   'Url': 'https://www.themoviedb.org/movie/928381'},
#  {'Name': 'The Commando',
#   'Rating': '67',
#   'Genre': 'Action,Crime,Thriller',
#   'Release Date': '01/07/2022',
#   'Runtime': '1h 33m',
#   'Url': 'https://www.themoviedb.org/movie/753232'},
#  {'Name': 'Blacklight',
#   'Rating': '54',
#   'Genre': 'Action,Thriller',
#   'Release Date': '02/10/2022',
#   'Runtime': '1h 44m',
#   'Url': 'https://www.themoviedb.org/movie/823625'},
#  {'Name': 'Turning Red',
#   'Rating': '75',
#   'Genre': 'Animation,Family,Comedy,Fantasy',
#   'Release Date': '03/10/2022',
#   'Runtime': '1h 40m',
#   'Url': 'https://www.themoviedb.org/movie/508947'},
#  {'Name': "The King's Man",
#   'Rating': '70',
#   'Genre': 'Action,Adventure,Thriller,War',
#   'Release Date': '01/14/2022',
#   'Runtime': '2h 11m',
#   'Url': 'https://www.themoviedb.org/movie/476669'},
#  {'Name': 'Red Notice',
#   'Rating': '68',
#   'Genre': 'Action,Comedy,Crime,Thriller',
#   'Release Date': '11/05/2021',
#   'Runtime': '1h 58m',
#   'Url': 'https://www.themoviedb.org/movie/512195'},
#  {'Name': 'Scream',
#   'Rating': '68',
#   'Genre': 'Horror,Mystery,Thriller',
#   'Release Date': '01/14/2022',
#   'Runtime': '1h 54m',
#   'Url': 'https://www.themoviedb.org/movie/646385'},
#  {'Name': "My Hero Academia: World Heroes' Mission",
#   'Rating': '73',
#   'Genre': 'Animation,Action,Fantasy,Adventure',
#   'Release Date': '08/06/2021',
#   'Runtime': '1h 45m',
#   'Url': 'https://www.themoviedb.org/movie/768744'},
#  {'Name': 'Desperate Riders',
#   'Rating': '58',
#   'Genre': 'Western,Action',
#   'Release Date': '02/25/2022',
#   'Runtime': '1h 30m',
#   'Url': 'https://www.themoviedb.org/movie/928999'},
#  {'Name': 'Kimi',
#   'Rating': '63',
#   'Genre': 'Thriller',
#   'Release Date': '02/10/2022',
#   'Runtime': '1h 29m',
#   'Url': 'https://www.themoviedb.org/movie/800510'},
#  {'Name': 'The Ice Age Adventures of Buck Wild',
#   'Rating': '71',
#   'Genre': 'Animation,Comedy,Adventure,Family',
#   'Release Date': '01/28/2022',
#   'Runtime': '1h 22m',
#   'Url': 'https://www.themoviedb.org/movie/774825'},
#  {'Name': 'Fistful of Vengeance',
#   'Rating': '54',
#   'Genre': 'Action,Crime,Fantasy',
#   'Release Date': '02/17/2022',
#   'Runtime': '1h 34m',
#   'Url': 'https://www.themoviedb.org/movie/890656'},
#  {'Name': 'Hotel Transylvania: Transformania',
#   'Rating': '70',
#   'Genre': 'Animation,Family,Fantasy,Comedy,Adventure',
#   'Release Date': '02/25/2022',
#   'Runtime': '1h 27m',
#   'Url': 'https://www.themoviedb.org/movie/585083'},
#  {'Name': 'Eternals',
#   'Rating': '72',
#   'Genre': 'Science Fiction',
#   'Release Date': '11/05/2021',
#   'Runtime': '2h 36m',
#   'Url': 'https://www.themoviedb.org/movie/524434'},
#  {'Name': 'Nightmare Alley',
#   'Rating': '71',
#   'Genre': 'Crime,Drama,Thriller',
#   'Release Date': '12/03/2021',
#   'Runtime': '2h 30m',
#   'Url': 'https://www.themoviedb.org/movie/597208'},
#  {'Name': 'Texas Chainsaw Massacre',
#   'Rating': '51',
#   'Genre': 'Horror,Thriller',
#   'Release Date': '02/18/2022',
#   'Runtime': '1h 21m',
#   'Url': 'https://www.themoviedb.org/movie/632727'}]

# %%
import pandas as pd

# %%
movies_df = pd.DataFrame(movies_scrape())

# %%
movies_df
# Out:
#                                        Name Rating  \
